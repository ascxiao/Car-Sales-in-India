# %% [markdown]
# <h1>Car Sales in India </h1>

# %% [markdown]
# (input text)

# %%
import pandas as pd

# Load the Excel file
file_path = 'Car Sales India 2024.xlsx'
df = pd.read_excel(file_path)

# Display the dataframe
display(df)
# Out:
#           Make        Model  January February  March  April   May    June  \
# 0      Citroen       Basalt        0        0      0      0     0     0.0
# 1      Citroen           C3      234      211    265    251   155    77.0
# 2      Citroen     Aircross      231      127    211     93   125   136.0
# 3      Citroen  C5 Aircross        1        0      0      1     0     0.0
# 4      Citroen         e-C3      184       83    530     59   235   126.0
# ..         ...          ...      ...      ...    ...    ...   ...     ...
# 82      Toyota       Taisor        0        0      0      0  2180  3185.0
# 83      Toyota     Vellfire       61       57     38      5    62   142.0
# 84  Volkswagen       Taigun     1275     1286   1588   1758  1561  1519.0
# 85  Volkswagen       Tiguan      113      102     94    108   102    85.0
# 86  Volkswagen       Virtus     1879     1631   1847   1183  1610  1656.0
#
#     July  August  September  October   November   December  Total  Segment  \
# ...
